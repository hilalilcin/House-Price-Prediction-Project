# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from sklearn.linear_model import LinearRegression,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

df = pd.read_excel("dataset.xlsx")
df.to_csv('dataset.csv',index = False)

# %%
# Exploratory Data Analysis.
df = pd.read_csv('dataset.csv')
print(df.head())
print(df.shape)
print(df.describe())
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# 0                575                      37.9
# 1               1240                      42.2
# 2               1060                      47.3
# 3                875                      54.8
# 4                491                      43.1
# (414, 9)
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# min                        0.000000   24.932070  121.473530
# 25%                        1.000000   24.963000  121.528085
# 50%                        4.000000   24.971100  121.538630
# 75%                        6.000000   24.977455  121.543305
# max                       10.000000   25.014590  121.566270
#
#        Number of bedrooms  House size (sqft)  House price of unit area
# count          414.000000         414.000000                414.000000
# mean             1.987923         931.475845                 37.980193
# std              0.818875         348.910269                 13.606488
# min              1.000000         402.000000                  7.600000
# 25%              1.000000         548.000000                 27.700000
# 50%              2.000000         975.000000                 38.450000
# 75%              3.000000        1234.750000                 46.600000
# max              3.000000        1500.000000                117.500000

# %%
# Checking Missing Values
print("Missing Values per Column:")
print(df.isnull().sum())

# Information of Dataset
(df.info())
# Out:
# Missing Values per Column:
# Transaction date                            0
# House Age                                   0
# Distance from nearest Metro station (km)    0
# Number of convenience stores                0
# latitude                                    0
# longitude                                   0
# Number of bedrooms                          0
# House size (sqft)                           0
# House price of unit area                    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Transaction date                          414 non-null    float64
#  1   House Age                                 414 non-null    float64
#  2   Distance from nearest Metro station (km)  414 non-null    float64
#  3   Number of convenience stores              414 non-null    int64
#  4   latitude                                  414 non-null    float64
#  5   longitude                                 414 non-null    float64
#  6   Number of bedrooms                        414 non-null    int64
#  7   House size (sqft)                         414 non-null    int64
#  8   House price of unit area                  414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 29.2 KB

# %%
# Extract the year and fractional part
df['Year'] = df['Transaction date'].astype(int)  
df['Fractional Year'] = df['Transaction date'] - df['Year'] 

# Convert fractional year into days
df['Days'] = (df['Fractional Year'] * 365).round().astype(int) 

#Create the formatted date
df['Transaction date (formatted)'] = pd.to_datetime(df['Year'], format='%Y') + pd.to_timedelta(df['Days'], unit='d')

print(df)
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0         2012.916667       32.0                                  84.87882
# 1         2012.916667       19.5                                 306.59470
# 2         2013.583333       13.3                                 561.98450
# 3         2013.500000       13.3                                 561.98450
# 4         2012.833333        5.0                                 390.56840
# ..                ...        ...                                       ...
# 409       2013.000000       13.7                                4082.01500
# 410       2012.666667        5.6                                  90.45606
# 411       2013.250000       18.8                                 390.96960
# 412       2013.000000        8.1                                 104.81010
# 413       2013.500000        6.5                                  90.45606
#
#      Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                              10  24.98298  121.54024                   1
# 1                               9  24.98034  121.53951                   2
# 2                               5  24.98746  121.54391                   3
# 3                               5  24.98746  121.54391                   2
# 4                               5  24.97937  121.54245                   1
# ..                            ...       ...        ...                 ...
# 409                             0  24.94155  121.50381                   3
# 410                             9  24.97433  121.54310                   2
# 411                             7  24.97923  121.53986                   1
# 412                             5  24.96674  121.54067                   1
# 413                             9  24.97433  121.54310                   2
#
#      House size (sqft)  House price of unit area  Year  Fractional Year  Days  \
# 0                  575                      37.9  2012         0.916667   335
# 1                 1240                      42.2  2012         0.916667   335
# 2                 1060                      47.3  2013         0.583333   213
# 3                  875                      54.8  2013         0.500000   182
# 4                  491                      43.1  2012         0.833333   304
# ..                 ...                       ...   ...              ...   ...
# 409                803                      15.4  2013         0.000000     0
# 410               1278                      50.0  2012         0.666667   243
# 411                503                      40.6  2013         0.250000    91
# 412                597                      52.5  2013         0.000000     0
# 413               1097                      63.9  2013         0.500000   182
#
#     Transaction date (formatted)
# 0                     2012-12-01
# 1                     2012-12-01
# 2                     2013-08-02
# 3                     2013-07-02
# 4                     2012-10-31
# ..                           ...
# 409                   2013-01-01
# 410                   2012-08-31
# 411                   2013-04-02
# 412                   2013-01-01
# 413                   2013-07-02
#
# [414 rows x 13 columns]

# %%
# Combining Distance and Latitude
df['Distance * Latitude'] = df['Distance from nearest Metro station (km)'] * df['latitude']
df['Distance * Longitude'] = df['Distance from nearest Metro station (km)'] * df['longitude']
print(df.columns)
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'House price of unit area',
#        'Year', 'Fractional Year', 'Days', 'Transaction date (formatted)',
#        'Distance * Latitude', 'Distance * Longitude'],
#       dtype='object')

# %%
#Target Variable Inspection
sns.histplot(df['House price of unit area'], kde=True)
plt.title("House Price Distribution")
plt.show()

# Relationship between target variable and Other Columns
sns.pairplot(df)
plt.show()

# %%
# Controlling Unique Values for Categorical Variables
for col in df.columns:
    unique_values = df[col].nunique()
    print(f"{col}: {unique_values} unique values")
# Out:
# Transaction date: 12 unique values
# House Age: 236 unique values
# Distance from nearest Metro station (km): 259 unique values
# Number of convenience stores: 11 unique values
# latitude: 234 unique values
# longitude: 232 unique values
# Number of bedrooms: 3 unique values
# House size (sqft): 328 unique values
# House price of unit area: 270 unique values

# %%
# Preprocessing Data: Handling Categorical and Continuous Variables
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import pandas as pd

# One-Hot Encoding for categorical features
categorical_features = ['Number of convenience stores', 'Number of bedrooms']
df_encoded = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# Normalization/Standardization for continuous features
scaler = StandardScaler()
continuous_features = ['House Age', 'Distance from nearest Metro station (km)', 
                        'House size (sqft)', 'House price of unit area']

df_encoded[continuous_features] = scaler.fit_transform(df_encoded[continuous_features])

print(df_encoded.head())
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667   1.255628                                 -0.792495
# 1       2012.916667   0.157086                                 -0.616612
# 2       2013.583333  -0.387791                                 -0.414015
# 3       2013.500000  -0.387791                                 -0.414015
# 4       2012.833333  -1.117223                                 -0.549997
#
#    latitude  longitude  House size (sqft)  House price of unit area  \
# 0  24.98298  121.54024          -1.022920                 -0.005901
# 1  24.98034  121.53951           0.885321                  0.310507
# 2  24.98746  121.54391           0.368804                  0.685782
# 3  24.98746  121.54391          -0.162059                  1.237656
# 4  24.97937  121.54245          -1.263960                  0.376732
#
#    Number of convenience stores_1  Number of convenience stores_2  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    Number of convenience stores_3  Number of convenience stores_4  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    Number of convenience stores_5  Number of convenience stores_6  \
# 0                           False                           False
# 1                           False                           False
# 2                            True                           False
# 3                            True                           False
# 4                            True                           False
#
#    Number of convenience stores_7  Number of convenience stores_8  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    Number of convenience stores_9  Number of convenience stores_10  \
# 0                           False                             True
# 1                            True                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
#    Number of bedrooms_2  Number of bedrooms_3
# 0                 False                 False
# 1                  True                 False
# 2                 False                  True
# 3                  True                 False
# 4                 False                 False

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Outlier Detection Boxplot
numerical_columns = ['House Age', 'Distance from nearest Metro station (km)', 
                     'House size (sqft)', 'House price of unit area']

# Outlier Visualization
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[numerical_columns])
plt.title("Outlier Visualization")
plt.xticks(rotation=45)
plt.show()

# Outlier detection using Z-Score method
z_scores = df[numerical_columns].apply(zscore)
outliers = (z_scores.abs() > 3)  

# Checking number of outliers 
print("Number of Outliers:")
for col in numerical_columns:
    print(f"{col}: {outliers[col].sum()} outliers")
    
#  Filtering The Outliers
df_cleaned = df[(z_scores.abs() <= 3).all(axis=1)]
print(f"Aykırı değerler çıkarıldıktan sonra kalan veri boyutu: {df_cleaned.shape}")
# Out:
# Number of Outliers:
# House Age: 0 outliers
# Distance from nearest Metro station (km): 5 outliers
# House size (sqft): 0 outliers
# House price of unit area: 1 outliers
# Aykırı değerler çıkarıldıktan sonra kalan veri boyutu: (408, 13)

# %%
#Clipping Outliers
#For Distance from the nearest Metro station (km)
upper_limit_distance = df['Distance from nearest Metro station (km)'].quantile(0.99)
df['Distance from nearest Metro station (km)'] = np.clip(
    df['Distance from nearest Metro station (km)'], None, upper_limit_distance
)

#For House price of unit area 
upper_limit_price = df['House price of unit area'].quantile(0.99)
df['House price of unit area'] = np.clip(
    df['House price of unit area'], None, upper_limit_price
)

# %%
# Clipping işlemi sonrası ilk 5 satırı kontrol et
print(df[['Distance from nearest Metro station (km)', 'House price of unit area']].head())
# Out:
#    Distance from nearest Metro station (km)  House price of unit area
# 0                                  84.87882                      37.9
# 1                                 306.59470                      42.2
# 2                                 561.98450                      47.3
# 3                                 561.98450                      54.8
# 4                                 390.56840                      43.1

# %%
# Data Visualization
corr_matrix = df.corr()
plt.figure(figsize=(15, 10))  

# Visualiasiton with heatmap
sns.heatmap(corr_matrix, annot=True, cmap='viridis', fmt='.2f', linewidths=0.5)
plt.title('Correlation Between Feautures')
plt.show()

# %%
# Correlation with the target variable ('House price of unit area')
target_corr = corr_matrix['House price of unit area'].sort_values(ascending=False)
print(target_corr)
# Out:
# House price of unit area                    1.000000
# Number of convenience stores                0.601236
# latitude                                    0.565830
# longitude                                   0.546868
# Transaction date                            0.082441
# Transaction date (formatted)                0.082326
# Year                                        0.077436
# Number of bedrooms                          0.053401
# House size (sqft)                           0.037784
# Fractional Year                            -0.044097
# Days                                       -0.044260
# House Age                                  -0.218476
# Distance from nearest Metro station (km)   -0.701333
# Name: House price of unit area, dtype: float64

# %%
#House price of unit area' with selecting low corelation
low_corr_features = corr_matrix['House price of unit area'][abs(corr_matrix['House price of unit area']) < 0.1].index
print("Low Correlation Features:", low_corr_features.tolist())
# Out:
# Low Correlation Features: ['Transaction date', 'Number of bedrooms', 'House size (sqft)', 'Year', 'Fractional Year', 'Days', 'Transaction date (formatted)']

# %%
# removes the features that have low correlation with the target variable from the dataframe.
X_reduced = df.drop(columns=low_corr_features)

#Split the data and build model with the remaining features
X = X_reduced.drop(columns=['House price of unit area'])  
y = df['House price of unit area']  # Target Variable

# %%
# Feature Selection
corr_matrix = df.corr()
# Selecting features that have a very high negative or positive correlation with the target variable
target_corr = corr_matrix['House price of unit area'].sort_values(ascending=False)
print("Hedef Değişkenle Korelasyonu En Yüksek Olan Özellikler:")
print(target_corr)
# Out:
# Hedef Değişkenle Korelasyonu En Yüksek Olan Özellikler:
# House price of unit area                    1.000000
# Number of convenience stores                0.601236
# latitude                                    0.565830
# longitude                                   0.546868
# Transaction date                            0.082441
# Transaction date (formatted)                0.082326
# Year                                        0.077436
# Number of bedrooms                          0.053401
# House size (sqft)                           0.037784
# Fractional Year                            -0.044097
# Days                                       -0.044260
# House Age                                  -0.218476
# Distance from nearest Metro station (km)   -0.701333
# Distance * Latitude                        -0.701337
# Distance * Longitude                       -0.701368
# Name: House price of unit area, dtype: float64

# %%
# Standardization
#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

#(Standardization) 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_reduced.drop(columns=['House price of unit area']))

# %%
from sklearn.model_selection import train_test_split

# Train test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"Training data size: X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"Test data size: X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Training data size: X_train: (331, 5), y_train: (331,)
# Test data size: X_test: (83, 5), y_test: (83,)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Distance from nearest Metro station (km)', y='House price of unit area', alpha=0.7)


plt.title('Relationship between Distance from nearest Metro station and Price', fontsize=14)
plt.xlabel('Distance from nearest Metro station (km)', fontsize=12)
plt.ylabel('House Price of per unit area)', fontsize=12)
plt.grid(True)
plt.show()



plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='latitude', y='House price of unit area', alpha=0.7)


plt.title('Relationship between latitude and Price', fontsize=14)
plt.xlabel('latitude', fontsize=12)
plt.ylabel('House Price of per unit area)', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Models 
# Linear Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Modeli oluşturma
model = LinearRegression()

# Modeli eğitme
model.fit(X_train, y_train)

# Test verileri üzerinde tahmin yapma
y_pred = model.predict(X_test)

# Performans değerlendirmesi
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("R2:", r2)
# Out:
# MAE: 5.2672576019445865
# MSE: 53.292201741113885
# R2: 0.6823302163846514

# %%
# Random Forest Regessor ,XGBRegressor, SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# XGBoost Regressor
xgb_model = XGBRegressor(n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# Support Vector Regressor
svr_model = SVR(kernel='rbf')
svr_model.fit(X_train, y_train)
svr_pred = svr_model.predict(X_test)

# Performance Metrics

print("Random Forest MAE:", mean_absolute_error(y_test, rf_pred))
print("Random Forest MSE:", mean_squared_error(y_test, rf_pred))
print("Random Forest R2:", r2_score(y_test, rf_pred))

print("XGBoost MAE:", mean_absolute_error(y_test, xgb_pred))
print("XGBoost MSE:", mean_squared_error(y_test, xgb_pred))
print("XGBoost R2:", r2_score(y_test, xgb_pred))

print("SVR MAE:", mean_absolute_error(y_test, svr_pred))
print("SVR MSE:", mean_squared_error(y_test, svr_pred))
print("SVR R2:", r2_score(y_test, svr_pred))

# (Model Tuning)
from sklearn.model_selection import GridSearchCV

#  GridSearch for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10]
}
grid_search_rf = GridSearchCV(RandomForestRegressor(random_state=42), param_grid_rf, cv=3)
grid_search_rf.fit(X_train, y_train)
print("Random Forest Best Parameters:", grid_search_rf.best_params_)

# GridSearch for Xgboost
param_grid_xgb = {
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.8, 1.0],
    'n_estimators': [100, 200, 300]
}
grid_search_xgb = GridSearchCV(XGBRegressor(), param_grid_xgb, cv=3)
grid_search_xgb.fit(X_train, y_train)
print("XGBoost Best Parameters:", grid_search_xgb.best_params_)

#Re-training with the best models
best_rf_model = grid_search_rf.best_estimator_
best_xgb_model = grid_search_xgb.best_estimator_

#Re-prediction
rf_pred_optimized = best_rf_model.predict(X_test)
xgb_pred_optimized = best_xgb_model.predict(X_test)

# "Performance Evaluation"
print("Optimized Random Forest MAE:", mean_absolute_error(y_test, rf_pred_optimized))
print("Optimized Random Forest MSE:", mean_squared_error(y_test, rf_pred_optimized))
print("Optimized Random Forest R2:", r2_score(y_test, rf_pred_optimized))

print("Optimized XGBoost MAE:", mean_absolute_error(y_test, xgb_pred_optimized))
print("Optimized XGBoost MSE:", mean_squared_error(y_test, xgb_pred_optimized))
print("Optimized XGBoost R2:", r2_score(y_test, xgb_pred_optimized))

# Performance Evaluation with Cross-Validation
from sklearn.model_selection import cross_val_score

# Random Forest Cross-Validation
cv_scores_rf = cross_val_score(best_rf_model, X_scaled, y, cv=5)
print(f"Random Forest Cross-Validation R2: {cv_scores_rf.mean()}")

# XGBoost Cross-Validation
cv_scores_xgb = cross_val_score(best_xgb_model, X_scaled, y, cv=5)
print(f"XGBoost Cross-Validation R2: {cv_scores_xgb.mean()}")
# Out:
# Random Forest MAE: 4.16939138927137
# Random Forest MSE: 33.00870731516431
# Random Forest R2: 0.8032382118275105
# XGBoost MAE: 4.831495691782021
# XGBoost MSE: 47.63961622204103
# XGBoost R2: 0.7160247450407233
# SVR MAE: 5.13151233955642
# SVR MSE: 52.71275103753254
# SVR R2: 0.6857842673266007
# Random Forest Best Parameters: {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 300}
# XGBoost Best Parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'subsample': 0.7}
# Optimized Random Forest MAE: 4.0343869230656715
# Optimized Random Forest MSE: 31.520964930605977
# Optimized Random Forest R2: 0.8121065037339683
# Optimized XGBoost MAE: 4.047650587702371
# Optimized XGBoost MSE: 32.387657254078135
# Optimized XGBoost R2: 0.8069402326124266
# Random Forest Cross-Validation R2: 0.740321074106274
# XGBoost Cross-Validation R2: 0.7512011659221057

# %%
from sklearn.linear_model import Lasso


# Lasso Regression modelini oluşturma
lasso = Lasso(alpha=0.1)  # alpha parametresi, modelin regularization gücünü ayarlar

# Modeli eğitme
lasso.fit(X_train_scaled, y_train)

# Tahmin yapma
y_pred = lasso.predict(X_test_scaled)

# Performans değerlendirmesi
print("Lasso Regression Performance:")
print(f"  R2 Score: {r2_score(y_test, y_pred):.4f}")
print(f"  Mean Absolute Error: {mean_absolute_error(y_test, y_pred):.4f}")
print(f"  Mean Squared Error: {mean_squared_error(y_test, y_pred):.4f}")
# Out:
# Lasso Regression Performance:
#   R2 Score: 0.6820
#   Mean Absolute Error: 5.2894
#   Mean Squared Error: 53.3427
